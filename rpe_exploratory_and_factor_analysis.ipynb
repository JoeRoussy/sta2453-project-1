# %% [markdown]
# # Factor Analysis

# %% [markdown]
# Factor analysis is a method for automatically finding latent variables in a data set. It assumes that observed variables are actually a linear combination of a number of latent factors. Often, we are aiming to find a smaller number of factors that explain trends in our data.
#
# This is how factor analysis differs from principal componant analysis. In PCA, the components are not interpretable, however, in factor analysis, we can see which observed variables are highly correlated with which factors and group observed variables according to which factors they are correlated with by looking at the loading. We can also see which factors are most important by their eiganvalues. Another technical difference between PCA and factor analysis is that in PCA, all the components are orthogonal but in factor analysis this does not need to be the case.

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import numpy as np
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity, calculate_kmo
from scipy.stats import pointbiserialr
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pingouin as pg

# %%
np.random.seed(5151)
rpe_df = pd.read_csv('./raw_data/rpe.csv')

# %% [markdown]
# To start with, we have 8860 observations.

# %% [markdown]
# ## Cleaning Data

# %%
len(rpe_df)
# Out:
# 8860

# %%
len(rpe_df[(rpe_df['ObjectiveRating'].isnull()) | (rpe_df['FocusRating'].isnull()) | (rpe_df['BestOutOfMyself'].isnull())])
# Out:
# 7151

# %% [markdown]
# Almost all the rows for the rpe data is missing at least one of: objective rating, focus rating, or best out of myself. We can impute the data for these columns but we need to keep in mind that we were missing a lot of this data.

# %%
# For datapoints that did do a training but their ratings are nan generate random ratings
# based on the current distribution of the values
for s in ['ObjectiveRating', 'FocusRating', 'BestOutOfMyself']:

    isnull = (rpe_df['Training']=='Yes') & (rpe_df[s].isnull())
    sample = rpe_df[(rpe_df['Training']=='Yes')][s].dropna().sample(isnull.sum(), replace=True).values
    rpe_df.loc[isnull, s] = sample

# %%
rpe_df['BestOutOfMyself'].value_counts()
# Out:
# Absolutely    6548
# Not at all    1072
# Somewhat       535
# Name: BestOutOfMyself, dtype: int64

# %%
rpe_df['BestOutOfMyself'] = rpe_df['BestOutOfMyself'].map({'Absolutely': 2, 'Not at all': 0, 'Somewhat': 1})

# %%
rpe_df['SessionType'].value_counts()
rpe_df['Training'] = rpe_df['Training'].map({'Yes': 1, 'No': 0})
rpe_df[rpe_df['PlayerID'] == 1]
# Out:
#             Date  PlayerID  Training        SessionType  Duration  RPE  \
# 9     2018-07-19         1         1             Skills      60.0  3.0
# 20    2018-07-18         1         0                NaN       NaN  NaN
# 29    2018-07-17         1         1             Skills      60.0  3.0
# 30    2018-07-17         1         1  Mobility/Recovery      30.0  0.0
# 47    2018-07-16         1         1             Skills      60.0  3.0
# 48    2018-07-16         1         1              Speed      30.0  2.0
# 71    2018-07-14         1         0                NaN       NaN  NaN
# 77    2018-07-13         1         0                NaN       NaN  NaN
# 120   2018-07-10         1         1             Skills      90.0  4.0
# 182   2018-07-08         1         0                NaN       NaN  NaN
# 192   2018-07-07         1         0                NaN       NaN  NaN
# 224   2018-07-05         1         1  Mobility/Recovery      30.0  0.0
# 225   2018-07-05         1         1             Skills      90.0  2.0
# 226   2018-07-05         1         1           Strength      40.0  1.0
# 254   2018-07-04         1         0                NaN       NaN  NaN
# 264   2018-07-03         1         1             Skills      90.0  5.0
# 287   2018-07-02         1         1              Speed      35.0  2.0
# 288   2018-07-02         1         1             Skills      90.0  2.0
# 289   2018-07-02         1         1           Strength      60.0  2.0
# 325   2018-07-01         1         0                NaN       NaN  NaN
# 332   2018-06-30         1         0                NaN       NaN  NaN
# 348   2018-06-29         1         1              Speed      60.0  3.0
# 349   2018-06-29         1         1             Skills      70.0  3.0
# 386   2018-06-28         1         1  Mobility/Recovery      30.0  0.0
# 387   2018-06-28         1         1             Skills      90.0  2.0
# 388   2018-06-28         1         1           Strength      60.0  2.0
# 420   2018-06-27         1         0                NaN       NaN  NaN
# 430   2018-06-26         1         1             Skills      90.0  7.0
# 456   2018-06-25         1         1              Speed      30.0  4.0
# 457   2018-06-25         1         1             Skills      70.0  3.0
# ...          ...       ...       ...                ...       ...  ...
# 8144  2017-08-28         1         1           Strength      90.0  4.0
# 8145  2017-08-28         1         1             Skills      60.0  3.0
# 8187  2017-08-27         1         0                NaN       NaN  NaN
# 8201  2017-08-26         1         0                NaN       NaN  NaN
# 8215  2017-08-25         1         1              Speed      60.0  4.0
# 8216  2017-08-25         1         1           Strength      90.0  6.0
# 8217  2017-08-25         1         1             Skills      60.0  4.0
# 8290  2017-08-23         1         1  Mobility/Recovery      40.0  0.0
# 8313  2017-08-22         1         1           Strength     110.0  6.0
# 8314  2017-08-22         1         1       Conditioning      60.0  7.0
# 8349  2017-08-21         1         1              Speed      60.0  3.0
# 8350  2017-08-21         1         1           Strength      90.0  5.0
# 8351  2017-08-21         1         1             Skills      40.0  1.0
# 8408  2017-08-19         1         0                NaN       NaN  NaN
# 8421  2017-08-18         1         1              Speed      60.0  4.0
# 8422  2017-08-18         1         1           Strength      90.0  7.0
# 8423  2017-08-18         1         1       Conditioning      60.0  6.0
# 8424  2017-08-18         1         1  Mobility/Recovery      30.0  0.0
# 8465  2017-08-17         1         1           Strength      60.0  4.0
# 8466  2017-08-17         1         1             Skills      90.0  3.0
# 8498  2017-08-16         1         1  Mobility/Recovery      45.0  0.0
# 8544  2017-08-14         1         1              Speed      60.0  4.0
# 8545  2017-08-14         1         1           Strength      90.0  5.0
# 8717  2017-08-07         1         1              Speed      60.0  3.0
# 8718  2017-08-07         1         1           Strength      90.0  4.0
# 8719  2017-08-07         1         1             Skills      60.0  3.0
# 8801  2017-08-03         1         0                NaN       NaN  NaN
# 8828  2017-08-02         1         0                NaN       NaN  NaN
# 8841  2017-08-01         1         1              Speed      60.0  3.0
# 8842  2017-08-01         1         1           Strength      90.0  4.0
#
#       SessionLoad  DailyLoad  AcuteLoad  ChronicLoad  AcuteChronicRatio  \
# 9           180.0      180.0       87.9       140.54               0.63
# 20            NaN        NaN       62.1       159.46               0.39
# 29          180.0      195.0       62.1       173.93               0.36
# 30           15.0        NaN        NaN          NaN                NaN
# 47          180.0      240.0       34.3       166.96               0.21
# 48           60.0        NaN        NaN          NaN                NaN
# 71            NaN        NaN       51.4       215.89               0.24
# 77            NaN        NaN       51.4       215.89               0.24
# 120         360.0      360.0       85.0       228.75               0.37
# 182           NaN        NaN       97.9       215.89               0.45
# 192           NaN        NaN      150.7       215.89               0.70
# 224          15.0      235.0      150.7       221.54               0.68
# 225         180.0        NaN        NaN          NaN                NaN
# 226          40.0        NaN        NaN          NaN                NaN
# 254           NaN        NaN      172.9       229.00               0.76
# 264         450.0      450.0      217.9       233.29               0.93
# 287          70.0      370.0      153.6       217.21               0.71
# 288         180.0        NaN        NaN          NaN                NaN
# 289         120.0        NaN        NaN          NaN                NaN
# 325           NaN        NaN      190.7       216.86               0.88
# 332           NaN        NaN      272.1       217.39               1.25
# 348         180.0      390.0      272.1       217.39               1.25
# 349         210.0        NaN        NaN          NaN                NaN
# 386          15.0      315.0      216.4       203.46               1.06
# 387         180.0        NaN        NaN          NaN                NaN
# 388         120.0        NaN        NaN          NaN                NaN
# 420           NaN        NaN      272.9       208.46               1.31
# 430         630.0      630.0      330.7       224.18               1.48
# 456         120.0      570.0      240.7       203.11               1.19
# 457         210.0        NaN        NaN          NaN                NaN
# ...           ...        ...        ...          ...                ...
# 8144        360.0        NaN        NaN          NaN                NaN
# 8145        180.0        NaN        NaN          NaN                NaN
# 8187          NaN        NaN      300.0       232.04               1.29
# 8201          NaN        NaN      395.7       232.04               1.71
# 8215        240.0     1020.0      395.7       232.04               1.71
# 8216        540.0        NaN        NaN          NaN                NaN
# 8217        240.0        NaN        NaN          NaN                NaN
# 8290          0.0        0.0      427.9       195.61               2.19
# 8313        660.0     1080.0      500.7       195.61               2.56
# 8314        420.0        NaN        NaN          NaN                NaN
# 8349        180.0      670.0      349.6       157.04               2.23
# 8350        450.0        NaN        NaN          NaN                NaN
# 8351         40.0        NaN        NaN          NaN                NaN
# 8408          NaN        NaN      352.4       133.11               2.65
# 8421        240.0     1245.0      352.4       133.11               2.65
# 8422        630.0        NaN        NaN          NaN                NaN
# 8423        360.0        NaN        NaN          NaN                NaN
# 8424         15.0        NaN        NaN          NaN                NaN
# 8465        240.0      510.0      174.6        88.64               1.97
# 8466        270.0        NaN        NaN          NaN                NaN
# 8498         22.0       22.0      101.7        70.43               1.44
# 8544        240.0      690.0       98.6        69.64               1.42
# 8545        450.0        NaN        NaN          NaN                NaN
# 8717        180.0      720.0      102.9        45.00               2.29
# 8718        360.0        NaN        NaN          NaN                NaN
# 8719        180.0        NaN        NaN          NaN                NaN
# 8801          NaN        NaN       77.1        19.29               4.00
# 8828          NaN        NaN        NaN          NaN                NaN
# 8841        180.0      540.0       77.1        19.29               4.00
# 8842        360.0        NaN        NaN          NaN                NaN
#
#       ObjectiveRating  FocusRating  BestOutOfMyself
# 9                 9.0          8.0              0.0
# 20                NaN          NaN              NaN
# 29                9.0          9.0              2.0
# 30                9.0          8.0              2.0
# 47                8.0          8.0              2.0
# 48                9.0          0.0              2.0
# 71                NaN          NaN              NaN
# 77                NaN          NaN              NaN
# 120               9.0          9.0              0.0
# 182               NaN          NaN              NaN
# 192               NaN          NaN              NaN
# 224              10.0          1.0              2.0
# 225               6.0         10.0              2.0
# 226               9.0          0.0              2.0
# 254               NaN          NaN              NaN
# 264               8.0          8.0              2.0
# 287               8.0         10.0              1.0
# 288               7.0         10.0              2.0
# 289               8.0          8.0              2.0
# 325               NaN          NaN              NaN
# 332               NaN          NaN              NaN
# 348               7.0          9.0              2.0
# 349               9.0          8.0              2.0
# 386               8.0          9.0              2.0
# 387               7.0          8.0              2.0
# 388               7.0          8.0              0.0
# 420               NaN          NaN              NaN
# 430               8.0          9.0              2.0
# 456               7.0          8.0              2.0
# 457               8.0          8.0              2.0
# ...               ...          ...              ...
# 8144             10.0         10.0              2.0
# 8145             10.0         10.0              2.0
# 8187              NaN          NaN              NaN
# 8201              NaN          NaN              2.0
# 8215             10.0         10.0              2.0
# 8216             10.0         10.0              2.0
# 8217             10.0         10.0              2.0
# 8290              0.0          6.0              2.0
# 8313             10.0          8.0              0.0
# 8314             10.0          8.0              2.0
# 8349             10.0         10.0              2.0
# 8350             10.0         10.0              2.0
# 8351             10.0         10.0              0.0
# 8408              NaN          NaN              NaN
# 8421             10.0          8.0              2.0
# 8422              9.0          7.0              2.0
# 8423              9.0         10.0              2.0
# 8424              8.0          8.0              2.0
# 8465              5.0          7.0              1.0
# 8466              5.0          7.0              1.0
# 8498              9.0          7.0              2.0
# 8544              9.0         10.0              2.0
# 8545              8.0          7.0              2.0
# 8717              7.0          8.0              2.0
# 8718              7.0          8.0              2.0
# 8719              7.0          8.0              0.0
# 8801              NaN          NaN              1.0
# 8828              0.0          0.0              NaN
# 8841              0.0          0.0              2.0
# 8842              0.0          0.0              2.0
#
# [576 rows x 14 columns]

# %% [markdown]
# # Recomputing Session Loads

# %% [markdown]
# Now we need to recompute sessionloads (since previous session loads were sometimes miscalculated) and consecutively recompute daily loads chronic loads and acute loads for both cases were a player had a training or not.

# %%
rpe_df['SessionLoad'] = rpe_df['Duration'] * rpe_df['RPE']

rpe_df.Date = pd.to_datetime(rpe_df.Date)
rpe_df = rpe_df.sort_values(by = 'Date', ascending = True)
print(rpe_df.head())
# Recomputing DailyLoad
rpe_df['DailyLoad'] = rpe_df.groupby(['Date','PlayerID'])['SessionLoad'].transform('sum')
rpe_df[rpe_df['Date'] == '2017-09-06']
# Out:
#            Date  PlayerID  Training SessionType  Duration  RPE  SessionLoad  \
# 8859 2017-08-01        15         1    Strength      60.0  4.0        240.0
# 8841 2017-08-01         1         1       Speed      60.0  3.0        180.0
# 8842 2017-08-01         1         1    Strength      90.0  4.0        360.0
# 8843 2017-08-01         3         1       Speed      45.0  5.0        225.0
# 8844 2017-08-01         3         1    Strength      90.0  5.0        450.0
#
#       DailyLoad  AcuteLoad  ChronicLoad  AcuteChronicRatio  ObjectiveRating  \
# 8859        NaN        NaN          NaN                NaN              6.0
# 8841      540.0       77.1        19.29                4.0              0.0
# 8842        NaN        NaN          NaN                NaN              0.0
# 8843      675.0       96.4        24.11                4.0              7.0
# 8844        NaN        NaN          NaN                NaN              7.0
#
#       FocusRating  BestOutOfMyself
# 8859          7.0              2.0
# 8841          0.0              2.0
# 8842          0.0              2.0
# 8843          7.0              2.0
# 8844          7.0              2.0
#            Date  PlayerID  Training        SessionType  Duration  RPE  \
# 7911 2017-09-06         8         1  Mobility/Recovery      60.0  0.0
# 7906 2017-09-06         1         1  Mobility/Recovery      45.0  0.0
# 7907 2017-09-06         2         1  Mobility/Recovery      45.0  1.0
# 7908 2017-09-06         3         1  Mobility/Recovery      60.0  3.0
# 7909 2017-09-06         3         1  Mobility/Recovery      30.0  3.0
# 7912 2017-09-06         9         1           Strength      90.0  5.0
# 7910 2017-09-06         7         1  Mobility/Recovery      45.0  1.0
# 7914 2017-09-06        10         1  Mobility/Recovery      45.0  0.0
# 7915 2017-09-06        11         1  Mobility/Recovery      60.0  2.0
# 7916 2017-09-06        11         1  Mobility/Recovery      60.0  1.0
# 7917 2017-09-06        13         1  Mobility/Recovery      45.0  0.0
# 7918 2017-09-06        13         1  Mobility/Recovery      30.0  0.0
# 7919 2017-09-06        16         1  Mobility/Recovery     180.0  2.0
# 7920 2017-09-06        17         1  Mobility/Recovery      50.0  0.0
# 7913 2017-09-06         9         1       Conditioning      45.0  6.0
#
#       SessionLoad  DailyLoad  AcuteLoad  ChronicLoad  AcuteChronicRatio  \
# 7911          0.0        0.0      527.1       560.89               0.94
# 7906          0.0        0.0      316.0       335.39               0.94
# 7907         45.0       45.0      257.1       296.96               0.87
# 7908        180.0      270.0      432.1       589.64               0.73
# 7909         90.0      270.0        NaN          NaN                NaN
# 7912        450.0      720.0      402.1       312.50               1.29
# 7910         45.0       45.0      452.4       542.21               0.83
# 7914          0.0        0.0      232.7       321.04               0.72
# 7915        120.0      180.0      454.3       561.96               0.81
# 7916         60.0      180.0        NaN          NaN                NaN
# 7917          0.0        0.0      636.4       657.86               0.97
# 7918          0.0        0.0        NaN          NaN                NaN
# 7919        360.0      360.0      223.6       196.43               1.14
# 7920          0.0        0.0      107.9       165.18               0.65
# 7913        270.0      720.0        NaN          NaN                NaN
#
#       ObjectiveRating  FocusRating  BestOutOfMyself
# 7911              9.0          8.0              2.0
# 7906              8.0          9.0              2.0
# 7907              8.0          9.0              2.0
# 7908              8.0          8.0              2.0
# 7909              8.0          8.0              2.0
# 7912              9.0          9.0              2.0
# 7910              9.0          7.0              2.0
# 7914              0.0          0.0              2.0
# 7915             10.0         10.0              2.0
# 7916             10.0         10.0              2.0
# 7917              9.0          5.0              2.0
# 7918              8.0          8.0              2.0
# 7919              4.0          4.0              2.0
# 7920              7.0          8.0              1.0
# 7913              9.0          9.0              2.0

# %% [markdown]
# # Recomputing Daily load, Acute Load and Chronic Load

# %%
rpe_df['DailyLoad'] = rpe_df.groupby(['Date','PlayerID'])['DailyLoad'].fillna(method='ffill')

# %%
temp = rpe_df[['Date','PlayerID','DailyLoad']].drop_duplicates()
past7Days = temp.groupby('PlayerID').rolling('7d', on='Date')['DailyLoad'].sum().reset_index()
past7Days['newAcuteLoad'] = (past7Days['DailyLoad'] / 7.).round(2)
past7Days = past7Days.drop(columns = 'DailyLoad')

rpe_df = pd.merge(rpe_df, past7Days, how="left", on=["Date", "PlayerID"])

# %%
past30Days = temp.groupby('PlayerID').rolling('30d', on='Date')['DailyLoad'].sum().reset_index()
past30Days['newChronicLoad'] = (past30Days['DailyLoad'] / 30.).round(2)
past30Days = past30Days.drop(columns = 'DailyLoad')

rpe_df = pd.merge(rpe_df, past30Days, how="left", on=["Date", "PlayerID"])
print(rpe_df[rpe_df['PlayerID'] == 1])
# Out:
#            Date  PlayerID  Training        SessionType  Duration  RPE  \
# 1    2017-08-01         1         1              Speed      60.0  3.0
# 2    2017-08-01         1         1           Strength      90.0  4.0
# 19   2017-08-02         1         0                NaN       NaN  NaN
# 41   2017-08-03         1         0                NaN       NaN  NaN
# 114  2017-08-07         1         1             Skills      60.0  3.0
# 115  2017-08-07         1         1           Strength      90.0  4.0
# 116  2017-08-07         1         1              Speed      60.0  3.0
# 290  2017-08-14         1         1           Strength      90.0  5.0
# 291  2017-08-14         1         1              Speed      60.0  4.0
# 342  2017-08-16         1         1  Mobility/Recovery      45.0  0.0
# 373  2017-08-17         1         1             Skills      90.0  3.0
# 374  2017-08-17         1         1           Strength      60.0  4.0
# 404  2017-08-18         1         1       Conditioning      60.0  6.0
# 411  2017-08-18         1         1  Mobility/Recovery      30.0  0.0
# 412  2017-08-18         1         1           Strength      90.0  7.0
# 413  2017-08-18         1         1              Speed      60.0  4.0
# 439  2017-08-19         1         0                NaN       NaN  NaN
# 482  2017-08-21         1         1             Skills      40.0  1.0
# 483  2017-08-21         1         1           Strength      90.0  5.0
# 484  2017-08-21         1         1              Speed      60.0  3.0
# 523  2017-08-22         1         1       Conditioning      60.0  7.0
# 524  2017-08-22         1         1           Strength     110.0  6.0
# 554  2017-08-23         1         1  Mobility/Recovery      40.0  0.0
# 618  2017-08-25         1         1             Skills      60.0  4.0
# 619  2017-08-25         1         1           Strength      90.0  6.0
# 620  2017-08-25         1         1              Speed      60.0  4.0
# 646  2017-08-26         1         0                NaN       NaN  NaN
# 660  2017-08-27         1         0                NaN       NaN  NaN
# 688  2017-08-28         1         1             Skills      60.0  3.0
# 689  2017-08-28         1         1           Strength      90.0  4.0
# ...         ...       ...       ...                ...       ...  ...
# 8373 2018-06-25         1         1             Skills      70.0  3.0
# 8374 2018-06-25         1         1              Speed      30.0  4.0
# 8409 2018-06-26         1         1             Skills      90.0  7.0
# 8431 2018-06-27         1         0                NaN       NaN  NaN
# 8450 2018-06-28         1         1           Strength      60.0  2.0
# 8451 2018-06-28         1         1             Skills      90.0  2.0
# 8452 2018-06-28         1         1  Mobility/Recovery      30.0  0.0
# 8488 2018-06-29         1         1             Skills      70.0  3.0
# 8489 2018-06-29         1         1              Speed      60.0  3.0
# 8513 2018-06-30         1         0                NaN       NaN  NaN
# 8528 2018-07-01         1         0                NaN       NaN  NaN
# 8543 2018-07-02         1         1           Strength      60.0  2.0
# 8549 2018-07-02         1         1             Skills      90.0  2.0
# 8550 2018-07-02         1         1              Speed      35.0  2.0
# 8580 2018-07-03         1         1             Skills      90.0  5.0
# 8596 2018-07-04         1         0                NaN       NaN  NaN
# 8615 2018-07-05         1         1           Strength      40.0  1.0
# 8616 2018-07-05         1         1             Skills      90.0  2.0
# 8617 2018-07-05         1         1  Mobility/Recovery      30.0  0.0
# 8660 2018-07-07         1         0                NaN       NaN  NaN
# 8669 2018-07-08         1         0                NaN       NaN  NaN
# 8725 2018-07-10         1         1             Skills      90.0  4.0
# 8778 2018-07-13         1         0                NaN       NaN  NaN
# 8788 2018-07-14         1         0                NaN       NaN  NaN
# 8796 2018-07-16         1         1             Skills      60.0  3.0
# 8797 2018-07-16         1         1              Speed      30.0  2.0
# 8814 2018-07-17         1         1             Skills      60.0  3.0
# 8815 2018-07-17         1         1  Mobility/Recovery      30.0  0.0
# 8832 2018-07-18         1         0                NaN       NaN  NaN
# 8840 2018-07-19         1         1             Skills      60.0  3.0
#
#       SessionLoad  DailyLoad  AcuteLoad  ChronicLoad  AcuteChronicRatio  \
# 1           180.0      540.0       77.1        19.29               4.00
# 2           360.0      540.0        NaN          NaN                NaN
# 19            NaN        0.0        NaN          NaN                NaN
# 41            NaN        0.0       77.1        19.29               4.00
# 114         180.0      720.0        NaN          NaN                NaN
# 115         360.0      720.0        NaN          NaN                NaN
# 116         180.0      720.0      102.9        45.00               2.29
# 290         450.0      690.0        NaN          NaN                NaN
# 291         240.0      690.0       98.6        69.64               1.42
# 342           0.0        0.0      101.7        70.43               1.44
# 373         270.0      510.0        NaN          NaN                NaN
# 374         240.0      510.0      174.6        88.64               1.97
# 404         360.0     1230.0        NaN          NaN                NaN
# 411           0.0     1230.0        NaN          NaN                NaN
# 412         630.0     1230.0        NaN          NaN                NaN
# 413         240.0     1230.0      352.4       133.11               2.65
# 439           NaN        0.0      352.4       133.11               2.65
# 482          40.0      670.0        NaN          NaN                NaN
# 483         450.0      670.0        NaN          NaN                NaN
# 484         180.0      670.0      349.6       157.04               2.23
# 523         420.0     1080.0        NaN          NaN                NaN
# 524         660.0     1080.0      500.7       195.61               2.56
# 554           0.0        0.0      427.9       195.61               2.19
# 618         240.0     1020.0        NaN          NaN                NaN
# 619         540.0     1020.0        NaN          NaN                NaN
# 620         240.0     1020.0      395.7       232.04               1.71
# 646           NaN        0.0      395.7       232.04               1.71
# 660           NaN        0.0      300.0       232.04               1.29
# 688         180.0      780.0        NaN          NaN                NaN
# 689         360.0      780.0        NaN          NaN                NaN
# ...           ...        ...        ...          ...                ...
# 8373        210.0      570.0        NaN          NaN                NaN
# 8374        120.0      570.0      240.7       203.11               1.19
# 8409        630.0      630.0      330.7       224.18               1.48
# 8431          NaN        0.0      272.9       208.46               1.31
# 8450        120.0      300.0        NaN          NaN                NaN
# 8451        180.0      300.0        NaN          NaN                NaN
# 8452          0.0      300.0      216.4       203.46               1.06
# 8488        210.0      390.0        NaN          NaN                NaN
# 8489        180.0      390.0      272.1       217.39               1.25
# 8513          NaN        0.0      272.1       217.39               1.25
# 8528          NaN        0.0      190.7       216.86               0.88
# 8543        120.0      370.0        NaN          NaN                NaN
# 8549        180.0      370.0        NaN          NaN                NaN
# 8550         70.0      370.0      153.6       217.21               0.71
# 8580        450.0      450.0      217.9       233.29               0.93
# 8596          NaN        0.0      172.9       229.00               0.76
# 8615         40.0      220.0        NaN          NaN                NaN
# 8616        180.0      220.0        NaN          NaN                NaN
# 8617          0.0      220.0      150.7       221.54               0.68
# 8660          NaN        0.0      150.7       215.89               0.70
# 8669          NaN        0.0       97.9       215.89               0.45
# 8725        360.0      360.0       85.0       228.75               0.37
# 8778          NaN        0.0       51.4       215.89               0.24
# 8788          NaN        0.0       51.4       215.89               0.24
# 8796        180.0      240.0       34.3       166.96               0.21
# 8797         60.0      240.0        NaN          NaN                NaN
# 8814        180.0      180.0       62.1       173.93               0.36
# 8815          0.0      180.0        NaN          NaN                NaN
# 8832          NaN        0.0       62.1       159.46               0.39
# 8840        180.0      180.0       87.9       140.54               0.63
#
#       ObjectiveRating  FocusRating  BestOutOfMyself  newAcuteLoad  \
# 1                 0.0          0.0              2.0         77.14
# 2                 0.0          0.0              2.0         77.14
# 19                0.0          0.0              NaN         77.14
# 41                NaN          NaN              1.0         77.14
# 114               7.0          8.0              0.0        180.00
# 115               7.0          8.0              2.0        180.00
# 116               7.0          8.0              2.0        180.00
# 290               8.0          7.0              2.0         98.57
# 291               9.0         10.0              2.0         98.57
# 342               9.0          7.0              2.0         98.57
# 373               5.0          7.0              1.0        171.43
# 374               5.0          7.0              1.0        171.43
# 404               9.0         10.0              2.0        347.14
# 411               8.0          8.0              2.0        347.14
# 412               9.0          7.0              2.0        347.14
# 413              10.0          8.0              2.0        347.14
# 439               NaN          NaN              NaN        347.14
# 482              10.0         10.0              0.0        344.29
# 483              10.0         10.0              2.0        344.29
# 484              10.0         10.0              2.0        344.29
# 523              10.0          8.0              2.0        498.57
# 524              10.0          8.0              0.0        498.57
# 554               0.0          6.0              2.0        498.57
# 618              10.0         10.0              2.0        395.71
# 619              10.0         10.0              2.0        395.71
# 620              10.0         10.0              2.0        395.71
# 646               NaN          NaN              2.0        395.71
# 660               NaN          NaN              NaN        395.71
# 688              10.0         10.0              2.0        411.43
# 689              10.0         10.0              2.0        411.43
# ...               ...          ...              ...           ...
# 8373              8.0          8.0              2.0        384.29
# 8374              7.0          8.0              2.0        384.29
# 8409              8.0          9.0              2.0        328.57
# 8431              NaN          NaN              NaN        328.57
# 8450              7.0          8.0              0.0        315.71
# 8451              7.0          8.0              2.0        315.71
# 8452              8.0          9.0              2.0        315.71
# 8488              9.0          8.0              2.0        270.00
# 8489              7.0          9.0              2.0        270.00
# 8513              NaN          NaN              NaN        270.00
# 8528              NaN          NaN              NaN        270.00
# 8543              8.0          8.0              2.0        241.43
# 8549              7.0         10.0              2.0        241.43
# 8550              8.0         10.0              1.0        241.43
# 8580              8.0          8.0              2.0        215.71
# 8596              NaN          NaN              NaN        215.71
# 8615              9.0          0.0              2.0        204.29
# 8616              6.0         10.0              2.0        204.29
# 8617             10.0          1.0              2.0        204.29
# 8660              NaN          NaN              NaN        148.57
# 8669              NaN          NaN              NaN        148.57
# 8725              9.0          9.0              0.0         82.86
# 8778              NaN          NaN              NaN         51.43
# 8788              NaN          NaN              NaN         51.43
# 8796              8.0          8.0              2.0         85.71
# 8797              9.0          0.0              2.0         85.71
# 8814              9.0          9.0              2.0         60.00
# 8815              9.0          8.0              2.0         60.00
# 8832              NaN          NaN              NaN         60.00
# 8840              9.0          8.0              0.0         85.71
#
#       newChronicLoad
# 1              18.00
# 2              18.00
# 19             18.00
# 41             18.00
# 114            42.00
# 115            42.00
# 116            42.00
# 290            65.00
# 291            65.00
# 342            65.00
# 373            82.00
# 374            82.00
# 404           123.00
# 411           123.00
# 412           123.00
# 413           123.00
# 439           123.00
# 482           145.33
# 483           145.33
# 484           145.33
# 523           181.33
# 524           181.33
# 554           181.33
# 618           215.33
# 619           215.33
# 620           215.33
# 646           215.33
# 660           215.33
# 688           241.33
# 689           241.33
# ...              ...
# 8373          223.00
# 8374          223.00
# 8409          244.00
# 8431          224.00
# 8450          217.67
# 8451          217.67
# 8452          217.67
# 8488          230.67
# 8489          230.67
# 8513          216.00
# 8528          201.00
# 8543          213.33
# 8549          213.33
# 8550          213.33
# 8580          228.33
# 8596          228.33
# 8615          223.67
# 8616          223.67
# 8617          223.67
# 8660          219.67
# 8669          205.27
# 8725          212.00
# 8778          212.00
# 8788          212.00
# 8796          208.00
# 8797          208.00
# 8814          214.00
# 8815          214.00
# 8832          194.33
# 8840          166.33
#
# [576 rows x 16 columns]

# %% [markdown]
# # Recomputing Acute Chronic Ratio

# %%
rpe_df.drop(['ChronicLoad','AcuteLoad'],axis = 1, inplace = True)
rpe_df.rename(columns = {'newChronicLoad':'ChronicLoad','newAcuteLoad':'AcuteLoad'}, inplace = True)
rpe_df['AcuteChronicRatio'] = (rpe_df['AcuteLoad'] / rpe_df['ChronicLoad']).round(2)
print(rpe_df[rpe_df['PlayerID'] == 1])
# Out:
#            Date  PlayerID  Training        SessionType  Duration  RPE  \
# 1    2017-08-01         1         1              Speed      60.0  3.0
# 2    2017-08-01         1         1           Strength      90.0  4.0
# 19   2017-08-02         1         0                NaN       NaN  NaN
# 41   2017-08-03         1         0                NaN       NaN  NaN
# 114  2017-08-07         1         1             Skills      60.0  3.0
# 115  2017-08-07         1         1           Strength      90.0  4.0
# 116  2017-08-07         1         1              Speed      60.0  3.0
# 290  2017-08-14         1         1           Strength      90.0  5.0
# 291  2017-08-14         1         1              Speed      60.0  4.0
# 342  2017-08-16         1         1  Mobility/Recovery      45.0  0.0
# 373  2017-08-17         1         1             Skills      90.0  3.0
# 374  2017-08-17         1         1           Strength      60.0  4.0
# 404  2017-08-18         1         1       Conditioning      60.0  6.0
# 411  2017-08-18         1         1  Mobility/Recovery      30.0  0.0
# 412  2017-08-18         1         1           Strength      90.0  7.0
# 413  2017-08-18         1         1              Speed      60.0  4.0
# 439  2017-08-19         1         0                NaN       NaN  NaN
# 482  2017-08-21         1         1             Skills      40.0  1.0
# 483  2017-08-21         1         1           Strength      90.0  5.0
# 484  2017-08-21         1         1              Speed      60.0  3.0
# 523  2017-08-22         1         1       Conditioning      60.0  7.0
# 524  2017-08-22         1         1           Strength     110.0  6.0
# 554  2017-08-23         1         1  Mobility/Recovery      40.0  0.0
# 618  2017-08-25         1         1             Skills      60.0  4.0
# 619  2017-08-25         1         1           Strength      90.0  6.0
# 620  2017-08-25         1         1              Speed      60.0  4.0
# 646  2017-08-26         1         0                NaN       NaN  NaN
# 660  2017-08-27         1         0                NaN       NaN  NaN
# 688  2017-08-28         1         1             Skills      60.0  3.0
# 689  2017-08-28         1         1           Strength      90.0  4.0
# ...         ...       ...       ...                ...       ...  ...
# 8373 2018-06-25         1         1             Skills      70.0  3.0
# 8374 2018-06-25         1         1              Speed      30.0  4.0
# 8409 2018-06-26         1         1             Skills      90.0  7.0
# 8431 2018-06-27         1         0                NaN       NaN  NaN
# 8450 2018-06-28         1         1           Strength      60.0  2.0
# 8451 2018-06-28         1         1             Skills      90.0  2.0
# 8452 2018-06-28         1         1  Mobility/Recovery      30.0  0.0
# 8488 2018-06-29         1         1             Skills      70.0  3.0
# 8489 2018-06-29         1         1              Speed      60.0  3.0
# 8513 2018-06-30         1         0                NaN       NaN  NaN
# 8528 2018-07-01         1         0                NaN       NaN  NaN
# 8543 2018-07-02         1         1           Strength      60.0  2.0
# 8549 2018-07-02         1         1             Skills      90.0  2.0
# 8550 2018-07-02         1         1              Speed      35.0  2.0
# 8580 2018-07-03         1         1             Skills      90.0  5.0
# 8596 2018-07-04         1         0                NaN       NaN  NaN
# 8615 2018-07-05         1         1           Strength      40.0  1.0
# 8616 2018-07-05         1         1             Skills      90.0  2.0
# 8617 2018-07-05         1         1  Mobility/Recovery      30.0  0.0
# 8660 2018-07-07         1         0                NaN       NaN  NaN
# 8669 2018-07-08         1         0                NaN       NaN  NaN
# 8725 2018-07-10         1         1             Skills      90.0  4.0
# 8778 2018-07-13         1         0                NaN       NaN  NaN
# 8788 2018-07-14         1         0                NaN       NaN  NaN
# 8796 2018-07-16         1         1             Skills      60.0  3.0
# 8797 2018-07-16         1         1              Speed      30.0  2.0
# 8814 2018-07-17         1         1             Skills      60.0  3.0
# 8815 2018-07-17         1         1  Mobility/Recovery      30.0  0.0
# 8832 2018-07-18         1         0                NaN       NaN  NaN
# 8840 2018-07-19         1         1             Skills      60.0  3.0
#
#       SessionLoad  DailyLoad  AcuteChronicRatio  ObjectiveRating  FocusRating  \
# 1           180.0      540.0               4.29              0.0          0.0
# 2           360.0      540.0               4.29              0.0          0.0
# 19            NaN        0.0               4.29              0.0          0.0
# 41            NaN        0.0               4.29              NaN          NaN
# 114         180.0      720.0               4.29              7.0          8.0
# 115         360.0      720.0               4.29              7.0          8.0
# 116         180.0      720.0               4.29              7.0          8.0
# 290         450.0      690.0               1.52              8.0          7.0
# 291         240.0      690.0               1.52              9.0         10.0
# 342           0.0        0.0               1.52              9.0          7.0
# 373         270.0      510.0               2.09              5.0          7.0
# 374         240.0      510.0               2.09              5.0          7.0
# 404         360.0     1230.0               2.82              9.0         10.0
# 411           0.0     1230.0               2.82              8.0          8.0
# 412         630.0     1230.0               2.82              9.0          7.0
# 413         240.0     1230.0               2.82             10.0          8.0
# 439           NaN        0.0               2.82              NaN          NaN
# 482          40.0      670.0               2.37             10.0         10.0
# 483         450.0      670.0               2.37             10.0         10.0
# 484         180.0      670.0               2.37             10.0         10.0
# 523         420.0     1080.0               2.75             10.0          8.0
# 524         660.0     1080.0               2.75             10.0          8.0
# 554           0.0        0.0               2.75              0.0          6.0
# 618         240.0     1020.0               1.84             10.0         10.0
# 619         540.0     1020.0               1.84             10.0         10.0
# 620         240.0     1020.0               1.84             10.0         10.0
# 646           NaN        0.0               1.84              NaN          NaN
# 660           NaN        0.0               1.84              NaN          NaN
# 688         180.0      780.0               1.70             10.0         10.0
# 689         360.0      780.0               1.70             10.0         10.0
# ...           ...        ...                ...              ...          ...
# 8373        210.0      570.0               1.72              8.0          8.0
# 8374        120.0      570.0               1.72              7.0          8.0
# 8409        630.0      630.0               1.35              8.0          9.0
# 8431          NaN        0.0               1.47              NaN          NaN
# 8450        120.0      300.0               1.45              7.0          8.0
# 8451        180.0      300.0               1.45              7.0          8.0
# 8452          0.0      300.0               1.45              8.0          9.0
# 8488        210.0      390.0               1.17              9.0          8.0
# 8489        180.0      390.0               1.17              7.0          9.0
# 8513          NaN        0.0               1.25              NaN          NaN
# 8528          NaN        0.0               1.34              NaN          NaN
# 8543        120.0      370.0               1.13              8.0          8.0
# 8549        180.0      370.0               1.13              7.0         10.0
# 8550         70.0      370.0               1.13              8.0         10.0
# 8580        450.0      450.0               0.94              8.0          8.0
# 8596          NaN        0.0               0.94              NaN          NaN
# 8615         40.0      220.0               0.91              9.0          0.0
# 8616        180.0      220.0               0.91              6.0         10.0
# 8617          0.0      220.0               0.91             10.0          1.0
# 8660          NaN        0.0               0.68              NaN          NaN
# 8669          NaN        0.0               0.72              NaN          NaN
# 8725        360.0      360.0               0.39              9.0          9.0
# 8778          NaN        0.0               0.24              NaN          NaN
# 8788          NaN        0.0               0.24              NaN          NaN
# 8796        180.0      240.0               0.41              8.0          8.0
# 8797         60.0      240.0               0.41              9.0          0.0
# 8814        180.0      180.0               0.28              9.0          9.0
# 8815          0.0      180.0               0.28              9.0          8.0
# 8832          NaN        0.0               0.31              NaN          NaN
# 8840        180.0      180.0               0.52              9.0          8.0
#
#       BestOutOfMyself  AcuteLoad  ChronicLoad
# 1                 2.0      77.14        18.00
# 2                 2.0      77.14        18.00
# 19                NaN      77.14        18.00
# 41                1.0      77.14        18.00
# 114               0.0     180.00        42.00
# 115               2.0     180.00        42.00
# 116               2.0     180.00        42.00
# 290               2.0      98.57        65.00
# 291               2.0      98.57        65.00
# 342               2.0      98.57        65.00
# 373               1.0     171.43        82.00
# 374               1.0     171.43        82.00
# 404               2.0     347.14       123.00
# 411               2.0     347.14       123.00
# 412               2.0     347.14       123.00
# 413               2.0     347.14       123.00
# 439               NaN     347.14       123.00
# 482               0.0     344.29       145.33
# 483               2.0     344.29       145.33
# 484               2.0     344.29       145.33
# 523               2.0     498.57       181.33
# 524               0.0     498.57       181.33
# 554               2.0     498.57       181.33
# 618               2.0     395.71       215.33
# 619               2.0     395.71       215.33
# 620               2.0     395.71       215.33
# 646               2.0     395.71       215.33
# 660               NaN     395.71       215.33
# 688               2.0     411.43       241.33
# 689               2.0     411.43       241.33
# ...               ...        ...          ...
# 8373              2.0     384.29       223.00
# 8374              2.0     384.29       223.00
# 8409              2.0     328.57       244.00
# 8431              NaN     328.57       224.00
# 8450              0.0     315.71       217.67
# 8451              2.0     315.71       217.67
# 8452              2.0     315.71       217.67
# 8488              2.0     270.00       230.67
# 8489              2.0     270.00       230.67
# 8513              NaN     270.00       216.00
# 8528              NaN     270.00       201.00
# 8543              2.0     241.43       213.33
# 8549              2.0     241.43       213.33
# 8550              1.0     241.43       213.33
# 8580              2.0     215.71       228.33
# 8596              NaN     215.71       228.33
# 8615              2.0     204.29       223.67
# 8616              2.0     204.29       223.67
# 8617              2.0     204.29       223.67
# 8660              NaN     148.57       219.67
# 8669              NaN     148.57       205.27
# 8725              0.0      82.86       212.00
# 8778              NaN      51.43       212.00
# 8788              NaN      51.43       212.00
# 8796              2.0      85.71       208.00
# 8797              2.0      85.71       208.00
# 8814              2.0      60.00       214.00
# 8815              2.0      60.00       214.00
# 8832              NaN      60.00       194.33
# 8840              0.0      85.71       166.33
#
# [576 rows x 14 columns]

# %% [markdown]
# We can now save the processed version of rpe data. Also before doing the factor analysis, since there are a lot of missing field for days that players did not do any training, it might be a good idea to separate the two datasets and do the factor analysis on them separately.

# %%
print(len(rpe_df))
rpe_df.to_csv('./processed_data/processed_rpe.csv')

training_yes = rpe_df[rpe_df['Training'] == 1].drop(['Training'], axis=1)
training_no = rpe_df[rpe_df['Training'] == 0].drop(['Training'], axis=1)
print(len(training_yes))
# Out:
# 8860
# 7622

# %%
print(len(training_no),len(training_no[training_no['SessionType'].isnull()]))
print(training_no['SessionType'].value_counts())
print(training_no[training_no['SessionType']=='Conditioning'])
print(training_no['ObjectiveRating'].value_counts())
print(training_no['FocusRating'].value_counts())
print(training_no['BestOutOfMyself'].value_counts())
# Out:
# 1238 1237
# Conditioning    1
# Name: SessionType, dtype: int64
#            Date  PlayerID   SessionType  Duration  RPE  SessionLoad  \
# 3241 2017-11-30         3  Conditioning      30.0  5.0        150.0
#
#       DailyLoad  AcuteChronicRatio  ObjectiveRating  FocusRating  \
# 3241     1180.0                0.9              8.0          8.0
#
#       BestOutOfMyself  AcuteLoad  ChronicLoad
# 3241              2.0     407.86       454.67
# 0.0    3
# 8.0    1
# 7.0    1
# Name: ObjectiveRating, dtype: int64
# 0.0    3
# 8.0    1
# 7.0    1
# Name: FocusRating, dtype: int64
# 2.0    449
# 1.0     60
# 0.0     24
# Name: BestOutOfMyself, dtype: int64

# %% [markdown]
# There was only one datapoint that by mistake the training field was marked as a No, while it was a conditioning training. So we add that to the training_yes group and remove it from the training_no group. Also since there were only 5 datapoints that had focus rating and objective rating we can remove these two columns from the training_no group.

# %%
print(len(training_yes))
tmp_df = training_no[training_no['SessionType']=='Conditioning']
training_yes = pd.concat([training_yes, tmp_df])
print(len(training_yes))
print(len(training_no))
training_no = training_no[training_no['SessionType'].isnull()]
print(len(training_no))
# Out:
# 7622
# 7623
# 1238
# 1237

# %%
# Removing rows that had dailyloads (since it means they did do
# trainings on that day after all and there are only 13 of them)
training_no = training_no[training_no['DailyLoad'] == 0]
print(len(training_no))
# Out:
# 1222

# %%
# Remove unnecessary columns
training_no.dropna(axis = 1, how = 'all',inplace = True)
training_no.drop(['ObjectiveRating', 'FocusRating','DailyLoad'],axis=1, inplace = True)
print(training_no.columns)
# Out:
# Index(['Date', 'PlayerID', 'AcuteChronicRatio', 'BestOutOfMyself', 'AcuteLoad',
#        'ChronicLoad'],
#       dtype='object')

# %% [markdown]
# Before preparing the data for factor analysis, it is also nice to see the correlation between different variables using repeated correlation measures:

# %%
corr_training =  training_yes.copy()
corr_training['SessionType'] = corr_training['SessionType'].map({'Combat': 0, 'Conditioning': 1,
                                                                 'Game': 2,
                                                                 'Mobility/Recovery': 3,
                                                                 'Skills': 4,
                                                                 'Speed': 5,'Strength': 6})
for i in corr_training.columns:
    if i == 'Date' or i == 'PlayerID':
        continue
        
    for j in corr_training.columns:
        if j == 'Date' or j == 'PlayerID' or i == j:
            continue
            
        print('Repeated Measures Correlation Result for {} and {}'.format(i, j))
        print(pg.rm_corr(data= corr_training, x=i, y=j, subject='PlayerID'))
# Out:
# Repeated Measures Correlation Result for SessionType and Duration
#              r   dof           pval         CI95%  power
# rm_corr  0.414  7603  3.220236e-312  [0.39, 0.43]    1.0
# Repeated Measures Correlation Result for SessionType and RPE
#              r   dof          pval           CI95%  power
# rm_corr -0.067  7603  4.552371e-09  [-0.09, -0.04]    1.0
# Repeated Measures Correlation Result for SessionType and SessionLoad
#              r   dof           pval         CI95%  power
# rm_corr  0.266  7603  3.545668e-123  [0.24, 0.29]    1.0
# Repeated Measures Correlation Result for SessionType and DailyLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.134  7603  1.229759e-31  [0.11, 0.16]    1.0
# Repeated Measures Correlation Result for SessionType and AcuteChronicRatio
#              r   dof          pval        CI95%  power
# rm_corr  0.074  7603  1.347399e-10  [0.05, 0.1]    1.0
# Repeated Measures Correlation Result for SessionType and ObjectiveRating
#              r   dof     pval         CI95%  power
# rm_corr -0.018  7603  0.10676  [-0.04, 0.0]  0.364
# Repeated Measures Correlation Result for SessionType and FocusRating
#              r   dof      pval          CI95%  power
# rm_corr -0.017  7603  0.134551  [-0.04, 0.01]  0.322
# Repeated Measures Correlation Result for SessionType and BestOutOfMyself
#              r   dof      pval          CI95%  power
# rm_corr -0.007  7603  0.519053  [-0.03, 0.02]  0.099
# Repeated Measures Correlation Result for SessionType and AcuteLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.064  7603  2.776779e-08  [0.04, 0.09]    1.0
# Repeated Measures Correlation Result for SessionType and ChronicLoad
#              r   dof      pval          CI95%  power
# rm_corr  0.006  7603  0.619971  [-0.02, 0.03]  0.079
# Repeated Measures Correlation Result for Duration and SessionType
#              r   dof           pval         CI95%  power
# rm_corr  0.414  7603  3.220219e-312  [0.39, 0.43]    1.0
# Repeated Measures Correlation Result for Duration and RPE
#              r   dof           pval         CI95%  power
# rm_corr  0.257  7603  1.386793e-114  [0.24, 0.28]    1.0
# Repeated Measures Correlation Result for Duration and SessionLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.803  7603   0.0  [0.79, 0.81]    1.0
# Repeated Measures Correlation Result for Duration and DailyLoad
#              r   dof           pval        CI95%  power
# rm_corr  0.377  7603  3.276575e-255  [0.36, 0.4]    1.0
# Repeated Measures Correlation Result for Duration and AcuteChronicRatio
#              r   dof          pval         CI95%  power
# rm_corr  0.138  7603  8.281085e-34  [0.12, 0.16]    1.0
# Repeated Measures Correlation Result for Duration and ObjectiveRating
#              r   dof      pval           CI95%  power
# rm_corr -0.029  7603  0.012794  [-0.05, -0.01]  0.702
# Repeated Measures Correlation Result for Duration and FocusRating
#              r   dof      pval           CI95%  power
# rm_corr -0.035  7603  0.002299  [-0.06, -0.01]  0.862
# Repeated Measures Correlation Result for Duration and BestOutOfMyself
#              r   dof      pval          CI95%  power
# rm_corr -0.003  7603  0.773791  [-0.03, 0.02]   0.06
# Repeated Measures Correlation Result for Duration and AcuteLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.235  7603  9.462059e-96  [0.21, 0.26]    1.0
# Repeated Measures Correlation Result for Duration and ChronicLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.096  7603  6.313742e-17  [0.07, 0.12]    1.0
# Repeated Measures Correlation Result for RPE and SessionType
#              r   dof          pval           CI95%  power
# rm_corr -0.067  7603  4.552371e-09  [-0.09, -0.04]    1.0
# Repeated Measures Correlation Result for RPE and Duration
#              r   dof           pval         CI95%  power
# rm_corr  0.257  7603  1.386798e-114  [0.24, 0.28]    1.0
# Repeated Measures Correlation Result for RPE and SessionLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.704  7603   0.0  [0.69, 0.72]    1.0
# Repeated Measures Correlation Result for RPE and DailyLoad
#              r   dof           pval         CI95%  power
# rm_corr  0.392  7603  1.496658e-277  [0.37, 0.41]    1.0
# Repeated Measures Correlation Result for RPE and AcuteChronicRatio
#              r   dof      pval          CI95%  power
# rm_corr  0.014  7603  0.219904  [-0.01, 0.04]  0.232
# Repeated Measures Correlation Result for RPE and ObjectiveRating
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7603  0.111315  [-0.04, 0.0]  0.357
# Repeated Measures Correlation Result for RPE and FocusRating
#             r   dof      pval         CI95%  power
# rm_corr  0.02  7603  0.086421  [-0.0, 0.04]  0.403
# Repeated Measures Correlation Result for RPE and BestOutOfMyself
#              r   dof     pval          CI95%  power
# rm_corr -0.009  7603  0.43908  [-0.03, 0.01]  0.121
# Repeated Measures Correlation Result for RPE and AcuteLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.131  7603  1.994480e-30  [0.11, 0.15]    1.0
# Repeated Measures Correlation Result for RPE and ChronicLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.087  7603  4.077740e-14  [0.06, 0.11]    1.0
# Repeated Measures Correlation Result for SessionLoad and SessionType
#              r   dof           pval         CI95%  power
# rm_corr  0.266  7603  3.545661e-123  [0.24, 0.29]    1.0
# Repeated Measures Correlation Result for SessionLoad and Duration
#              r   dof  pval         CI95%  power
# rm_corr  0.803  7603   0.0  [0.79, 0.81]    1.0
# Repeated Measures Correlation Result for SessionLoad and RPE
#              r   dof  pval         CI95%  power
# rm_corr  0.704  7603   0.0  [0.69, 0.72]    1.0
# Repeated Measures Correlation Result for SessionLoad and DailyLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.505  7603   0.0  [0.49, 0.52]    1.0
# Repeated Measures Correlation Result for SessionLoad and AcuteChronicRatio
#              r   dof          pval         CI95%  power
# rm_corr  0.112  7603  9.571720e-23  [0.09, 0.13]    1.0
# Repeated Measures Correlation Result for SessionLoad and ObjectiveRating
#              r   dof      pval           CI95%  power
# rm_corr -0.037  7603  0.001329  [-0.06, -0.01]  0.894
# Repeated Measures Correlation Result for SessionLoad and FocusRating
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7603  0.108236  [-0.04, 0.0]  0.362
# Repeated Measures Correlation Result for SessionLoad and BestOutOfMyself
#              r   dof      pval          CI95%  power
# rm_corr -0.005  7603  0.687592  [-0.03, 0.02]  0.069
# Repeated Measures Correlation Result for SessionLoad and AcuteLoad
#              r   dof           pval         CI95%  power
# rm_corr  0.252  7603  1.192362e-110  [0.23, 0.27]    1.0
# Repeated Measures Correlation Result for SessionLoad and ChronicLoad
#              r   dof          pval        CI95%  power
# rm_corr  0.121  7603  4.374301e-26  [0.1, 0.14]    1.0
# Repeated Measures Correlation Result for DailyLoad and SessionType
#              r   dof          pval         CI95%  power
# rm_corr  0.134  7603  1.229758e-31  [0.11, 0.16]    1.0
# Repeated Measures Correlation Result for DailyLoad and Duration
#              r   dof           pval        CI95%  power
# rm_corr  0.377  7603  3.276575e-255  [0.36, 0.4]    1.0
# Repeated Measures Correlation Result for DailyLoad and RPE
#              r   dof           pval         CI95%  power
# rm_corr  0.392  7603  1.496644e-277  [0.37, 0.41]    1.0
# Repeated Measures Correlation Result for DailyLoad and SessionLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.505  7603   0.0  [0.49, 0.52]    1.0
# Repeated Measures Correlation Result for DailyLoad and AcuteChronicRatio
#              r   dof          pval         CI95%  power
# rm_corr  0.213  7605  8.002747e-79  [0.19, 0.23]    1.0
# Repeated Measures Correlation Result for DailyLoad and ObjectiveRating
#              r   dof      pval           CI95%  power
# rm_corr -0.036  7605  0.001566  [-0.06, -0.01]  0.885
# Repeated Measures Correlation Result for DailyLoad and FocusRating
#              r   dof      pval         CI95%  power
# rm_corr -0.019  7605  0.092882  [-0.04, 0.0]   0.39
# Repeated Measures Correlation Result for DailyLoad and BestOutOfMyself
#              r   dof      pval         CI95%  power
# rm_corr  0.022  7605  0.057328  [-0.0, 0.04]  0.477
# Repeated Measures Correlation Result for DailyLoad and AcuteLoad
#              r   dof  pval        CI95%  power
# rm_corr  0.487  7605   0.0  [0.47, 0.5]    1.0
# Repeated Measures Correlation Result for DailyLoad and ChronicLoad
#              r   dof          pval        CI95%  power
# rm_corr  0.224  7605  2.850311e-87  [0.2, 0.25]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and SessionType
#              r   dof          pval        CI95%  power
# rm_corr  0.074  7603  1.347399e-10  [0.05, 0.1]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and Duration
#              r   dof          pval         CI95%  power
# rm_corr  0.138  7603  8.281089e-34  [0.12, 0.16]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and RPE
#              r   dof      pval          CI95%  power
# rm_corr  0.014  7603  0.219904  [-0.01, 0.04]  0.232
# Repeated Measures Correlation Result for AcuteChronicRatio and SessionLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.112  7603  9.571723e-23  [0.09, 0.13]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and DailyLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.213  7605  8.002685e-79  [0.19, 0.23]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and ObjectiveRating
#              r   dof     pval          CI95%  power
# rm_corr -0.009  7605  0.44856  [-0.03, 0.01]  0.118
# Repeated Measures Correlation Result for AcuteChronicRatio and FocusRating
#              r   dof      pval           CI95%  power
# rm_corr -0.039  7605  0.000682  [-0.06, -0.02]  0.925
# Repeated Measures Correlation Result for AcuteChronicRatio and BestOutOfMyself
#              r   dof      pval        CI95%  power
# rm_corr  0.023  7605  0.046105  [0.0, 0.05]  0.514
# Repeated Measures Correlation Result for AcuteChronicRatio and AcuteLoad
#             r   dof           pval         CI95%  power
# rm_corr  0.34  7605  1.025381e-204  [0.32, 0.36]    1.0
# Repeated Measures Correlation Result for AcuteChronicRatio and ChronicLoad
#              r   dof  pval          CI95%  power
# rm_corr -0.478  7605   0.0  [-0.5, -0.46]    1.0
# Repeated Measures Correlation Result for ObjectiveRating and SessionType
#              r   dof     pval         CI95%  power
# rm_corr -0.018  7603  0.10676  [-0.04, 0.0]  0.364
# Repeated Measures Correlation Result for ObjectiveRating and Duration
#              r   dof      pval           CI95%  power
# rm_corr -0.029  7603  0.012794  [-0.05, -0.01]  0.702
# Repeated Measures Correlation Result for ObjectiveRating and RPE
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7603  0.111315  [-0.04, 0.0]  0.357
# Repeated Measures Correlation Result for ObjectiveRating and SessionLoad
#              r   dof      pval           CI95%  power
# rm_corr -0.037  7603  0.001329  [-0.06, -0.01]  0.894
# Repeated Measures Correlation Result for ObjectiveRating and DailyLoad
#              r   dof      pval           CI95%  power
# rm_corr -0.036  7605  0.001566  [-0.06, -0.01]  0.885
# Repeated Measures Correlation Result for ObjectiveRating and AcuteChronicRatio
#              r   dof     pval          CI95%  power
# rm_corr -0.009  7605  0.44856  [-0.03, 0.01]  0.118
# Repeated Measures Correlation Result for ObjectiveRating and FocusRating
#              r   dof           pval         CI95%  power
# rm_corr  0.338  7605  3.670989e-203  [0.32, 0.36]    1.0
# Repeated Measures Correlation Result for ObjectiveRating and BestOutOfMyself
#              r   dof      pval         CI95%  power
# rm_corr  0.055  7605  0.000001  [0.03, 0.08]  0.998
# Repeated Measures Correlation Result for ObjectiveRating and AcuteLoad
#              r   dof      pval          CI95%  power
# rm_corr -0.014  7605  0.237678  [-0.04, 0.01]  0.219
# Repeated Measures Correlation Result for ObjectiveRating and ChronicLoad
#              r   dof     pval          CI95%  power
# rm_corr -0.025  7605  0.03025  [-0.05, -0.0]  0.582
# Repeated Measures Correlation Result for FocusRating and SessionType
#              r   dof      pval          CI95%  power
# rm_corr -0.017  7603  0.134551  [-0.04, 0.01]  0.322
# Repeated Measures Correlation Result for FocusRating and Duration
#              r   dof      pval           CI95%  power
# rm_corr -0.035  7603  0.002299  [-0.06, -0.01]  0.862
# Repeated Measures Correlation Result for FocusRating and RPE
#             r   dof      pval         CI95%  power
# rm_corr  0.02  7603  0.086421  [-0.0, 0.04]  0.403
# Repeated Measures Correlation Result for FocusRating and SessionLoad
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7603  0.108236  [-0.04, 0.0]  0.362
# Repeated Measures Correlation Result for FocusRating and DailyLoad
#              r   dof      pval         CI95%  power
# rm_corr -0.019  7605  0.092882  [-0.04, 0.0]   0.39
# Repeated Measures Correlation Result for FocusRating and AcuteChronicRatio
#              r   dof      pval           CI95%  power
# rm_corr -0.039  7605  0.000682  [-0.06, -0.02]  0.925
# Repeated Measures Correlation Result for FocusRating and ObjectiveRating
#              r   dof           pval         CI95%  power
# rm_corr  0.338  7605  3.671014e-203  [0.32, 0.36]    1.0
# Repeated Measures Correlation Result for FocusRating and BestOutOfMyself
#             r   dof          pval        CI95%  power
# rm_corr  0.08  7605  2.795940e-12  [0.06, 0.1]    1.0
# Repeated Measures Correlation Result for FocusRating and AcuteLoad
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7605  0.123477  [-0.04, 0.0]  0.338
# Repeated Measures Correlation Result for FocusRating and ChronicLoad
#              r   dof     pval          CI95%  power
# rm_corr  0.014  7605  0.23339  [-0.01, 0.04]  0.222
# Repeated Measures Correlation Result for BestOutOfMyself and SessionType
#              r   dof      pval          CI95%  power
# rm_corr -0.007  7603  0.519053  [-0.03, 0.02]  0.099
# Repeated Measures Correlation Result for BestOutOfMyself and Duration
#              r   dof      pval          CI95%  power
# rm_corr -0.003  7603  0.773791  [-0.03, 0.02]   0.06
# Repeated Measures Correlation Result for BestOutOfMyself and RPE
#              r   dof     pval          CI95%  power
# rm_corr -0.009  7603  0.43908  [-0.03, 0.01]  0.121
# Repeated Measures Correlation Result for BestOutOfMyself and SessionLoad
#              r   dof      pval          CI95%  power
# rm_corr -0.005  7603  0.687592  [-0.03, 0.02]  0.069
# Repeated Measures Correlation Result for BestOutOfMyself and DailyLoad
#              r   dof      pval         CI95%  power
# rm_corr  0.022  7605  0.057328  [-0.0, 0.04]  0.477
# Repeated Measures Correlation Result for BestOutOfMyself and AcuteChronicRatio
#              r   dof      pval        CI95%  power
# rm_corr  0.023  7605  0.046105  [0.0, 0.05]  0.514
# Repeated Measures Correlation Result for BestOutOfMyself and ObjectiveRating
#              r   dof      pval         CI95%  power
# rm_corr  0.055  7605  0.000001  [0.03, 0.08]  0.998
# Repeated Measures Correlation Result for BestOutOfMyself and FocusRating
#             r   dof          pval        CI95%  power
# rm_corr  0.08  7605  2.795943e-12  [0.06, 0.1]    1.0
# Repeated Measures Correlation Result for BestOutOfMyself and AcuteLoad
#              r   dof      pval         CI95%  power
# rm_corr  0.049  7605  0.000023  [0.03, 0.07]  0.989
# Repeated Measures Correlation Result for BestOutOfMyself and ChronicLoad
#              r   dof          pval         CI95%  power
# rm_corr  0.068  7605  3.749540e-09  [0.05, 0.09]    1.0
# Repeated Measures Correlation Result for AcuteLoad and SessionType
#              r   dof          pval         CI95%  power
# rm_corr  0.064  7603  2.776778e-08  [0.04, 0.09]    1.0
# Repeated Measures Correlation Result for AcuteLoad and Duration
#              r   dof          pval         CI95%  power
# rm_corr  0.235  7603  9.462059e-96  [0.21, 0.26]    1.0
# Repeated Measures Correlation Result for AcuteLoad and RPE
#              r   dof          pval         CI95%  power
# rm_corr  0.131  7603  1.994479e-30  [0.11, 0.15]    1.0
# Repeated Measures Correlation Result for AcuteLoad and SessionLoad
#              r   dof           pval         CI95%  power
# rm_corr  0.252  7603  1.192362e-110  [0.23, 0.27]    1.0
# Repeated Measures Correlation Result for AcuteLoad and DailyLoad
#              r   dof  pval        CI95%  power
# rm_corr  0.487  7605   0.0  [0.47, 0.5]    1.0
# Repeated Measures Correlation Result for AcuteLoad and AcuteChronicRatio
#             r   dof           pval         CI95%  power
# rm_corr  0.34  7605  1.025404e-204  [0.32, 0.36]    1.0
# Repeated Measures Correlation Result for AcuteLoad and ObjectiveRating
#              r   dof      pval          CI95%  power
# rm_corr -0.014  7605  0.237678  [-0.04, 0.01]  0.219
# Repeated Measures Correlation Result for AcuteLoad and FocusRating
#              r   dof      pval         CI95%  power
# rm_corr -0.018  7605  0.123477  [-0.04, 0.0]  0.338
# Repeated Measures Correlation Result for AcuteLoad and BestOutOfMyself
#              r   dof      pval         CI95%  power
# rm_corr  0.049  7605  0.000023  [0.03, 0.07]  0.989
# Repeated Measures Correlation Result for AcuteLoad and ChronicLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.491  7605   0.0  [0.47, 0.51]    1.0
# Repeated Measures Correlation Result for ChronicLoad and SessionType
#              r   dof      pval          CI95%  power
# rm_corr  0.006  7603  0.619971  [-0.02, 0.03]  0.079
# Repeated Measures Correlation Result for ChronicLoad and Duration
#              r   dof          pval         CI95%  power
# rm_corr  0.096  7603  6.313742e-17  [0.07, 0.12]    1.0
# Repeated Measures Correlation Result for ChronicLoad and RPE
#              r   dof          pval         CI95%  power
# rm_corr  0.087  7603  4.077738e-14  [0.06, 0.11]    1.0
# Repeated Measures Correlation Result for ChronicLoad and SessionLoad
#              r   dof          pval        CI95%  power
# rm_corr  0.121  7603  4.374301e-26  [0.1, 0.14]    1.0
# Repeated Measures Correlation Result for ChronicLoad and DailyLoad
#              r   dof          pval        CI95%  power
# rm_corr  0.224  7605  2.850311e-87  [0.2, 0.25]    1.0
# Repeated Measures Correlation Result for ChronicLoad and AcuteChronicRatio
#              r   dof  pval          CI95%  power
# rm_corr -0.478  7605   0.0  [-0.5, -0.46]    1.0
# Repeated Measures Correlation Result for ChronicLoad and ObjectiveRating
#              r   dof     pval          CI95%  power
# rm_corr -0.025  7605  0.03025  [-0.05, -0.0]  0.582
# Repeated Measures Correlation Result for ChronicLoad and FocusRating
#              r   dof     pval          CI95%  power
# rm_corr  0.014  7605  0.23339  [-0.01, 0.04]  0.222
# Repeated Measures Correlation Result for ChronicLoad and BestOutOfMyself
#              r   dof          pval         CI95%  power
# rm_corr  0.068  7605  3.749535e-09  [0.05, 0.09]    1.0
# Repeated Measures Correlation Result for ChronicLoad and AcuteLoad
#              r   dof  pval         CI95%  power
# rm_corr  0.491  7605   0.0  [0.47, 0.51]    1.0

# %%
# Convert categorical session type to dummy variable
training_yes = pd.get_dummies(training_yes, columns = ['SessionType'])

# %% [markdown]
# One of the interesting things that the repeated measure correlation shows us is that the correlation between duration and RPE is 0.257, which shows that we can not ignore one of these vraibles and probably a function of the two such as their product is indeed a reasonable estimate of session load.

# %%
training_no.to_csv('./processed_data/training_no.csv')
training_yes.to_csv('./processed_data/training_yes.csv')

# %% [markdown]
# ### Repeated measures correlation

# %% [markdown]
# Before we perform any partiular tests for suitability, we should make sure there are not any columns that are correlated in our dataset.

# %%
player_data_yes = training_yes.groupby('PlayerID',as_index = False).mean()
print(player_data_yes.head())
player_id_series = player_data_yes['PlayerID']
new_df_yes = player_data_yes.drop(['PlayerID'], axis=1)
print(new_df_yes.corr())
chi_square_value,p_value = calculate_bartlett_sphericity(new_df_yes)
print(chi_square_value, p_value)

yes_without_session_type = new_df_yes.drop(['SessionType_Combat',
                                        'SessionType_Conditioning',
                                       'SessionType_Game',
                                       'SessionType_Mobility/Recovery',
                                       'SessionType_Skills',
                                       'SessionType_Speed',
                                       'SessionType_Strength'],axis=1)
print(yes_without_session_type.columns)

kmo_all,kmo_model=calculate_kmo(yes_without_session_type)
print(kmo_all, kmo_model)
# Out:
#    PlayerID   Duration       RPE  SessionLoad   DailyLoad  AcuteChronicRatio  \
# 0         1  62.807203  3.476695   247.175847  667.213983           1.141208
# 1         2  51.758621  4.241379   236.977688  724.131313           1.258909
# 2         3  58.376569  4.995816   300.866109  783.217573           1.253975
# 3         4  63.384804  4.497549   295.147059  727.541667           1.242892
# 4         5  56.828571  4.281633   253.873469  666.591837           1.387388
#
#    ObjectiveRating  FocusRating  BestOutOfMyself   AcuteLoad  ChronicLoad  \
# 0         8.031780     8.218220         1.728814  371.749788   345.053305
# 1         8.046465     8.149495         1.666667  390.753374   339.576566
# 2         8.033473     7.981172         1.922594  467.025377   411.348703
# 3         7.801471     7.867647         1.708333  397.827108   345.876838
# 4         8.273469     8.575510         1.644898  275.206571   230.881633
#
#    SessionType_Combat  SessionType_Conditioning  SessionType_Game  \
# 0            0.012712                  0.120763          0.046610
# 1            0.044444                  0.117172          0.038384
# 2            0.004184                  0.161088          0.054393
# 3            0.014706                  0.112745          0.078431
# 4            0.016327                  0.175510          0.057143
#
#    SessionType_Mobility/Recovery  SessionType_Skills  SessionType_Speed  \
# 0                       0.088983            0.283898           0.165254
# 1                       0.163636            0.250505           0.155556
# 2                       0.102510            0.213389           0.173640
# 3                       0.061275            0.257353           0.191176
# 4                       0.093878            0.146939           0.175510
#
#    SessionType_Strength
# 0              0.281780
# 1              0.226263
# 2              0.290795
# 3              0.284314
# 4              0.334694
#                                Duration       RPE  SessionLoad  DailyLoad  \
# Duration                       1.000000  0.196419     0.617356   0.207185
# RPE                            0.196419  1.000000     0.853377   0.729002
# SessionLoad                    0.617356  0.853377     1.000000   0.692228
# DailyLoad                      0.207185  0.729002     0.692228   1.000000
# AcuteChronicRatio             -0.087977 -0.022921    -0.232845  -0.397183
# ObjectiveRating               -0.180877  0.018630     0.080027   0.348076
# FocusRating                   -0.274935  0.163731     0.079354   0.298391
# BestOutOfMyself                0.465902  0.341532     0.458715   0.188105
# AcuteLoad                      0.047311  0.470750     0.518612   0.795081
# ChronicLoad                    0.034095  0.350638     0.432617   0.734749
# SessionType_Combat            -0.143115 -0.093294    -0.259340  -0.004274
# SessionType_Conditioning      -0.251782  0.040604    -0.037155  -0.414693
# SessionType_Game               0.282837  0.169528     0.234218   0.133111
# SessionType_Mobility/Recovery -0.576161 -0.434704    -0.502702   0.007983
# SessionType_Skills             0.360870  0.277039     0.315762   0.513013
# SessionType_Speed              0.512313  0.400905     0.441764   0.013516
# SessionType_Strength           0.569142  0.130943     0.352598  -0.299667
#
#                                AcuteChronicRatio  ObjectiveRating  \
# Duration                               -0.087977        -0.180877
# RPE                                    -0.022921         0.018630
# SessionLoad                            -0.232845         0.080027
# DailyLoad                              -0.397183         0.348076
# AcuteChronicRatio                       1.000000        -0.474718
# ObjectiveRating                        -0.474718         1.000000
# FocusRating                            -0.172694         0.679098
# BestOutOfMyself                         0.128945         0.076550
# AcuteLoad                              -0.767247         0.481863
# ChronicLoad                            -0.842965         0.536126
# SessionType_Combat                      0.412501        -0.356330
# SessionType_Conditioning                0.273942         0.249945
# SessionType_Game                       -0.087589        -0.256776
# SessionType_Mobility/Recovery          -0.400776         0.633236
# SessionType_Skills                     -0.113622        -0.433971
# SessionType_Speed                       0.276460        -0.716143
# SessionType_Strength                    0.242706        -0.143332
#
#                                FocusRating  BestOutOfMyself  AcuteLoad  \
# Duration                         -0.274935         0.465902   0.047311
# RPE                               0.163731         0.341532   0.470750
# SessionLoad                       0.079354         0.458715   0.518612
# DailyLoad                         0.298391         0.188105   0.795081
# AcuteChronicRatio                -0.172694         0.128945  -0.767247
# ObjectiveRating                   0.679098         0.076550   0.481863
# FocusRating                       1.000000         0.014310   0.330119
# BestOutOfMyself                   0.014310         1.000000   0.056768
# AcuteLoad                         0.330119         0.056768   1.000000
# ChronicLoad                       0.333235         0.005957   0.986889
# SessionType_Combat               -0.426329        -0.025999  -0.352712
# SessionType_Conditioning          0.419476         0.172838  -0.272598
# SessionType_Game                 -0.171065         0.030029   0.132326
# SessionType_Mobility/Recovery     0.371453        -0.445577   0.350334
# SessionType_Skills               -0.294293         0.077636   0.291421
# SessionType_Speed                -0.495984         0.216305  -0.292341
# SessionType_Strength             -0.170711         0.437732  -0.431632
#
#                                ChronicLoad  SessionType_Combat  \
# Duration                          0.034095           -0.143115
# RPE                               0.350638           -0.093294
# SessionLoad                       0.432617           -0.259340
# DailyLoad                         0.734749           -0.004274
# AcuteChronicRatio                -0.842965            0.412501
# ObjectiveRating                   0.536126           -0.356330
# FocusRating                       0.333235           -0.426329
# BestOutOfMyself                   0.005957           -0.025999
# AcuteLoad                         0.986889           -0.352712
# ChronicLoad                       1.000000           -0.366191
# SessionType_Combat               -0.366191            1.000000
# SessionType_Conditioning         -0.289185           -0.454614
# SessionType_Game                  0.121186            0.150834
# SessionType_Mobility/Recovery     0.431839           -0.220950
# SessionType_Skills                0.235701            0.360716
# SessionType_Speed                -0.362321            0.184997
# SessionType_Strength             -0.434181           -0.275859
#
#                                SessionType_Conditioning  SessionType_Game  \
# Duration                                      -0.251782          0.282837
# RPE                                            0.040604          0.169528
# SessionLoad                                   -0.037155          0.234218
# DailyLoad                                     -0.414693          0.133111
# AcuteChronicRatio                              0.273942         -0.087589
# ObjectiveRating                                0.249945         -0.256776
# FocusRating                                    0.419476         -0.171065
# BestOutOfMyself                                0.172838          0.030029
# AcuteLoad                                     -0.272598          0.132326
# ChronicLoad                                   -0.289185          0.121186
# SessionType_Combat                            -0.454614          0.150834
# SessionType_Conditioning                       1.000000         -0.301900
# SessionType_Game                              -0.301900          1.000000
# SessionType_Mobility/Recovery                 -0.011703         -0.251021
# SessionType_Skills                            -0.758495          0.217332
# SessionType_Speed                             -0.197210          0.214464
# SessionType_Strength                           0.409693         -0.061958
#
#                                SessionType_Mobility/Recovery  \
# Duration                                           -0.576161
# RPE                                                -0.434704
# SessionLoad                                        -0.502702
# DailyLoad                                           0.007983
# AcuteChronicRatio                                  -0.400776
# ObjectiveRating                                     0.633236
# FocusRating                                         0.371453
# BestOutOfMyself                                    -0.445577
# AcuteLoad                                           0.350334
# ChronicLoad                                         0.431839
# SessionType_Combat                                 -0.220950
# SessionType_Conditioning                           -0.011703
# SessionType_Game                                   -0.251021
# SessionType_Mobility/Recovery                       1.000000
# SessionType_Skills                                 -0.384307
# SessionType_Speed                                  -0.900753
# SessionType_Strength                               -0.591521
#
#                                SessionType_Skills  SessionType_Speed  \
# Duration                                 0.360870           0.512313
# RPE                                      0.277039           0.400905
# SessionLoad                              0.315762           0.441764
# DailyLoad                                0.513013           0.013516
# AcuteChronicRatio                       -0.113622           0.276460
# ObjectiveRating                         -0.433971          -0.716143
# FocusRating                             -0.294293          -0.495984
# BestOutOfMyself                          0.077636           0.216305
# AcuteLoad                                0.291421          -0.292341
# ChronicLoad                              0.235701          -0.362321
# SessionType_Combat                       0.360716           0.184997
# SessionType_Conditioning                -0.758495          -0.197210
# SessionType_Game                         0.217332           0.214464
# SessionType_Mobility/Recovery           -0.384307          -0.900753
# SessionType_Skills                       1.000000           0.452185
# SessionType_Speed                        0.452185           1.000000
# SessionType_Strength                    -0.336796           0.501572
#
#                                SessionType_Strength
# Duration                                   0.569142
# RPE                                        0.130943
# SessionLoad                                0.352598
# DailyLoad                                 -0.299667
# AcuteChronicRatio                          0.242706
# ObjectiveRating                           -0.143332
# FocusRating                               -0.170711
# BestOutOfMyself                            0.437732
# AcuteLoad                                 -0.431632
# ChronicLoad                               -0.434181
# SessionType_Combat                        -0.275859
# SessionType_Conditioning                   0.409693
# SessionType_Game                          -0.061958
# SessionType_Mobility/Recovery             -0.591521
# SessionType_Skills                        -0.336796
# SessionType_Speed                          0.501572
# SessionType_Strength                       1.000000
# nan nan
# Index(['Duration', 'RPE', 'SessionLoad', 'DailyLoad', 'AcuteChronicRatio',
#        'ObjectiveRating', 'FocusRating', 'BestOutOfMyself', 'AcuteLoad',
#        'ChronicLoad'],
#       dtype='object')
# [0.17924986 0.35860768 0.39354302 0.58420887 0.50954501 0.32682286
#  0.74077681 0.36135085 0.54042484 0.54530769] 0.438629224311416
# //anaconda3/lib/python3.7/site-packages/factor_analyzer/factor_analyzer.py:118: RuntimeWarning: invalid value encountered in log
#   statistic = -np.log(corr_det) * (n - 1 - (2 * p + 5) / 6)

# %% [markdown]
# ### Adequacy Tests for factor analysis

# %%
player_data_no = training_no.groupby('PlayerID',as_index = False).mean()
new_df_no = player_data_no.drop(['PlayerID'], axis=1)

no_without_nan_columns = new_df_no.drop(['BestOutOfMyself'],axis=1)

# Chi square test for factor analysis
chi_square_value,p_value = calculate_bartlett_sphericity(no_without_nan_columns)
print(chi_square_value, p_value)

# kmo test for factor analysis
kmo_all,kmo_model=calculate_kmo(no_without_nan_columns)
print(kmo_all, kmo_model)
# Out:
# 71.45673357377878 1.0263585459218795e-15
# [0.11161378 0.34029549 0.35685836] 0.29071599489238514

# %% [markdown]
# # Factor analysis

# %%
def factor_scree_plot(factor_num, data, rotation = None):
    factor_number_tester = FactorAnalyzer(n_factors= factor_num, rotation= rotation) # Using number of factors = number of columns
    factor_number_tester.fit(data) 
    ev, v = factor_number_tester.get_eigenvalues()

    plt.scatter(range(1, data.shape[1]+1),ev)
    plt.plot(range(1, data.shape[1]+1),ev)
    plt.title('Scree Plot')
    plt.xlabel('Factors')
    plt.ylabel('Eigenvalue')
    plt.grid()
    plt.show()

def view_factor_loadings(factor_num, data, rotation = None):
    
    fa = FactorAnalyzer(factor_num, rotation= rotation)
    fa.fit(data)
    print(data.columns)
    print(fa.loadings_)
    print(np.where(fa.loadings_>0.7))
    print(fa.get_factor_variance())

# %%
print(new_df_yes.columns)
factor_scree_plot(10, new_df_yes, "varimax")
view_factor_loadings(4, new_df_yes, "varimax")
# Out:
# Index(['Duration', 'RPE', 'SessionLoad', 'DailyLoad', 'AcuteChronicRatio',
#        'ObjectiveRating', 'FocusRating', 'BestOutOfMyself', 'AcuteLoad',
#        'ChronicLoad', 'SessionType_Combat', 'SessionType_Conditioning',
#        'SessionType_Game', 'SessionType_Mobility/Recovery',
#        'SessionType_Skills', 'SessionType_Speed', 'SessionType_Strength'],
#       dtype='object')
# Index(['Duration', 'RPE', 'SessionLoad', 'DailyLoad', 'AcuteChronicRatio',
#        'ObjectiveRating', 'FocusRating', 'BestOutOfMyself', 'AcuteLoad',
#        'ChronicLoad', 'SessionType_Combat', 'SessionType_Conditioning',
#        'SessionType_Game', 'SessionType_Mobility/Recovery',
#        'SessionType_Skills', 'SessionType_Speed', 'SessionType_Strength'],
#       dtype='object')
# [[ 0.14718711  0.76807301  0.32984586  0.06312331]
#  [ 0.03901437  0.27527341  0.03424177  0.89971804]
#  [ 0.28815232  0.62122009  0.10275714  0.71146967]
#  [ 0.48203683 -0.06389481  0.24691448  0.79785672]
#  [-0.88350069  0.00511242 -0.08344958  0.02752502]
#  [ 0.58066677 -0.21491108 -0.57906478  0.14307972]
#  [ 0.29403853 -0.21834208 -0.5858944   0.30460126]
#  [-0.04320934  0.4611468  -0.07258781  0.29442051]
#  [ 0.84389551 -0.12227278  0.09113195  0.48405597]
#  [ 0.91723239 -0.13991159  0.07746796  0.3596205 ]
#  [-0.46098574 -0.29558038  0.48881343  0.01971512]
#  [-0.24855749  0.17975939 -0.88613619  0.01174763]
#  [ 0.05436902  0.13424436  0.34865093  0.09698894]
#  [ 0.52212044 -0.69511588 -0.34166301 -0.29375371]
#  [ 0.06421055  0.00532766  0.82419251  0.32496188]
#  [-0.42110289  0.60852527  0.48773313  0.18999604]
#  [-0.24544335  0.89074443 -0.28207752 -0.12358669]]
# (array([ 0,  1,  2,  3,  8,  9, 14, 16]), array([1, 3, 3, 3, 0, 0, 2, 1]))
# (array([3.88967287, 3.18142284, 3.14583563, 2.77377061]), array([0.22880429, 0.18714252, 0.18504915, 0.16316298]), array([0.22880429, 0.41594681, 0.60099596, 0.76415894]))

# %% [markdown]
# These factors are hard to interpret. Given how much data we are missing for some columns, we will used the acute chronic ratio for the measure of training load as we are assuming that this will have a relationship with performance.

# %% [markdown]
# # PCA on RPE data

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(player_data_yes)
print(principal_components)

HORIZONTAL_OFFSET = 0
VERTICAL_OFFSET = 0

fig, ax = plt.subplots()
ax.scatter(principal_components[:, 0], principal_components[:, 1])

for i in range(len(player_id_series)):
    ax.annotate(str(i + 1), (principal_components[i, 0] + HORIZONTAL_OFFSET, principal_components[i, 1] + VERTICAL_OFFSET))
# Out:
# [[   7.55692532   23.07353124]
#  [ -30.22735546  -11.42717982]
#  [-158.27140451  -18.27688724]
#  [ -48.79359381  -29.51872457]
#  [ 128.26755305  -64.95245042]
#  [-166.78504482  -75.23192975]
#  [-106.93871602   -7.03929445]
#  [ -59.84874108    5.20639585]
#  [  76.54875216   87.90442198]
#  [  86.78293298   38.47683713]
#  [-196.19355538    6.55377792]
#  [ 252.50701698   26.88493554]
#  [ -65.09274981   76.52479748]
#  [ -11.39095157  -29.38840444]
#  [ 209.47465882  -75.87733854]
#  [ -74.99214158   51.43010677]
#  [ 157.39641472   -4.34259468]]

# %% [markdown]
# It is interesting how the rpe data is less clustered than the wellness data when we visualized them using PCA.
